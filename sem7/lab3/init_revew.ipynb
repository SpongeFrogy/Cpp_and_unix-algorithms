# %%
from model import Model
from plot_settings import *
import numpy as np
from copy import deepcopy
from scipy import stats
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.10.11)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
plot_settings()

# %% [markdown]
# # Модель, когда только зеленый сигнал светофора

# %%
model = Model([[50] for _ in range(22)])

# %% [markdown]
# 1 симуляция в `__main__`

# %%
# %%time
r = model.simulate_one()
# Out:
# CPU times: total: 5.31 s
# Wall time: 6.57 s

# %% [markdown]
# 1 симуляция в `subProcess`

# %%
# %%time
r = model.simulate(n_eval=1)

# %% [markdown]
# 5 параллельных `subProcess`

# %%
# %%time
res = model.simulate(n_eval=5)
# Out:
# CPU times: total: 0 ns
# Wall time: 17.2 s

# %% [markdown]
# 5 последовательных цикла в `__main__`

# %%
# %%time
r = model.simulate_one()
r = model.simulate_one()
r = model.simulate_one()
r = model.simulate_one()
r = model.simulate_one()
# Out:
# CPU times: total: 29.8 s
# Wall time: 50.6 s

# %%
res = model.simulate(n_eval=5)

# %%
for t, sc in res:
    plt.plot(t, sc, linewidth=1)
plt.xlabel("time")
plt.ylabel("score")
# Out:
# Text(0, 0.5, 'score')

# %% [markdown]
# # Модель с параметрами зеленый 5, красный 5

# %%
model = Model([[5, 5] for _ in range(22)])

# %%
res = model.simulate(n_eval=5)

# %%
for t, sc in res:
    print(-np.mean(sc[100:]))
# Out:
# 100.49203129779261
# 99.59590671719832
# 100.5236420637305
# 100.41534719860384
# 100.42487830781225

# %%
0.5*np.log(0.5)*
# Out:
# -0.34657359027997264

# %%
for t, sc in res:
    plt.plot(t, sc, linewidth=1)
plt.xlabel("time")
plt.ylabel("score")
# Out:
# Text(0, 0.5, 'score')

# %% [markdown]
# # Модель с оптимальными параметрами

# %%
best_params =  [1.1920113103730348, 4.430956320551089, 3.6877756799328036, 5.121266995867331, 7.083965454042074, 7.5035100636979735, 2.1931999341570516, 1.6125847348113558, 6.458520348768374, 6.7946017769075855,  8.594513502317968,  1.7188217511331978,  7.804993695362211,  8.464979152877978,  2.812516023893759,  6.498284436108028,  2.101823142510497,  1.4714330475450588,  3.669071672853657,  4.860414639458732,  7.865208354574876,  2.0914867462644544]
model = Model([[p, 10-p] for p in best_params])

# %%
res = model.simulate(n_eval=5)

# %%
for t, sc in res:
    print(np.mean(sc))
# Out:
# -76.49404266270872
# -76.6310224365208
# -75.74952666675401
# -77.13834558314288
# -76.77937389089183

# %%
for t, sc in res:
    plt.plot(t, sc, linewidth=1)
plt.xlabel("time")
plt.ylabel("score")
# Out:
# Text(0, 0.5, 'score')

# %% [markdown]
# # Модель с параметрами зеленый - 40, красный -10

# %%
model = Model([[4, 6] for _ in range(22)])

# %%
res = model.simulate(n_eval=5)

# %%
for t, sc in res:
    plt.plot(t, sc, linewidth=1)
plt.xlabel("time")
plt.ylabel("score")
# Out:
# Text(0, 0.5, 'score')
